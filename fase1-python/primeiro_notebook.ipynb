# %% [markdown]
# <a href="https://colab.research.google.com/github/Nathanwlima/python-journey/blob/main/fase1-python/primeiro_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Google Colab funcionando!")
# Out:
# Google Colab funcionando!
